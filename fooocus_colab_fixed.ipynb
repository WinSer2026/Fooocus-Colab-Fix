# %% [markdown]
# # Fooocus Colab - Fix Completo 2026
#
# Corrige DOIS problemas:
# 1. `numpy>=2.0` incompatível com `cupy` → ImportError
# 2. `starlette≥0.29` incompatível com `gradio==3.41.2` → TypeError: unhashable type: 'dict'
#
# **Instruções:**
# 1. Execute a célula 1 abaixo
# 2. **REINICIE O RUNTIME** (Runtime > Restart session)
# 3. Execute a célula 2

# %%
# === FIX DE DEPENDÊNCIAS ===
# !pip uninstall -y cupy cupy-cuda11x cupy-cuda12x numpy -y
# !pip install "numpy==1.26.4" "cupy-cuda12x==13.3.0" "pygit2==1.15.1"
# !pip install rfc3987
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
print('✅ Dependências corrigidas! Reinicie o runtime agora.')

# %% [markdown]
# ⚠️ **REINICIE O RUNTIME AGORA!** (Runtime > Restart session)
# ⚠️ Depois de reiniciar, execute a célula 2

# %%
# === CLONAR E RODAR FOOOCUS ===
# %cd /content
# !rm -rf Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Fix: pin Gradio/Starlette/FastAPI versões compatíveis
# !echo 'fastapi==0.104.1' >> requirements_versions.txt
# !echo 'starlette==0.27.0' >> requirements_versions.txt
# !echo 'pydantic==1.10.19' >> requirements_versions.txt
# !python entry_with_update.py --share --always-high-vram
# Para anime: adicione --preset anime
# Para realistic: adicione --preset realistic
