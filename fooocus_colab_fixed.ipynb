# %% [markdown]
# # Fooocus - Colab Fix 2026
#
# Este notebook corrige os problemas de compatibilidade com o ambiente atual do Google Colab.
# **Problema original:** `ImportError: numpy.core.multiarray failed to import` devido à incompatibilidade entre numpy>=2.0 e cupy-cuda12x.

# %%
# === PASSO 1: Corrigir dependências conflitantes ===
# !pip uninstall -y numpy cupy cupy-cuda11x cupy-cuda12x 2>/dev/null
# !pip install "numpy==1.26.4" "cupy-cuda12x==13.3.0" "pygit2==1.15.1" --force-reinstall
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install rfc3987
print('✅ Dependências corrigidas!')

# %%
# === PASSO 2: Reiniciar o runtime (obrigatório) ===
# Após rodar esta célula, vá em: Runtime > Restart session
# Ou use: Menu > Runtime > Restart runtime
print('⚠️ AGORA REINICIE O RUNTIME (Runtime > Restart session)')
print('⚠️ Após reiniciar, rode a próxima célula!')

# %%
# === PASSO 3: Clonar e rodar Fooocus ===
# %cd /content
# !rm -rf Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Para usar preset anime: --preset anime
# Para usar preset realistic: --preset realistic
